# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAbdullah768/Relational-Data-Engineering/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MUHAMMAD ABDULLAH**
#
# # **u-36897**
#
# # **Mat-No 29474**

# %%
import pandas as pd

# %% [markdown]
# **Files Locations**

# %%
friends_file_location = "friends_table.csv"
posts_file_location = "posts_table.csv"
reactions_file_location = "reactions_table.csv"
user_file_location = "user_table.csv"

# %% [markdown]
# **Reading the csv Files**

# %%
friends_df = pd.read_csv(friends_file_location)
posts_df = pd.read_csv(posts_file_location)
reactions_df = pd.read_csv(reactions_file_location)
user_df = pd.read_csv(user_file_location)

# %% [markdown]
# **Reading of all the files for better understanding of the data**

# %%
user_df
# Out:
#          Surname      Name  Age  Subscription Date
# 0          Smith     Sarah   30         1588157373
# 1         Picard  Francine   32         1588161732
# 2           Roth      Hans   40         1588157337
# 3          Pomme       Ali   28         1588165636
# 4       Di Lillo     Jordi   42         1588156042
# ..           ...       ...  ...                ...
# 995         Kirk       Lee   19         1588160246
# 996        Pomme     Franz   40         1588159625
# 997       Gwahsi    Thomas   40         1588165504
# 998  Beierlorzer  Jean-Luc   32         1588151074
# 999     Thronton     Franz   28         1588171183
#
# [1000 rows x 4 columns]

# %%
user_df['user_id'] = user_df.index +1
user_df
# Out:
#          Surname      Name  Age  Subscription Date  user_id
# 0          Smith     Sarah   30         1588157373        1
# 1         Picard  Francine   32         1588161732        2
# 2           Roth      Hans   40         1588157337        3
# 3          Pomme       Ali   28         1588165636        4
# 4       Di Lillo     Jordi   42         1588156042        5
# ..           ...       ...  ...                ...      ...
# 995         Kirk       Lee   19         1588160246      996
# 996        Pomme     Franz   40         1588159625      997
# 997       Gwahsi    Thomas   40         1588165504      998
# 998  Beierlorzer  Jean-Luc   32         1588151074      999
# 999     Thronton     Franz   28         1588171183     1000
#
# [1000 rows x 5 columns]

# %% [markdown]
# # **Q1) What is the most common age in the social network? How many people share it?**

# %% [markdown]
# **Creating index coloumn and also counting of the people according to the age group and new coloumn with the counting is named as age "distribution count"**

# %%
temp_df = (user_df.groupby(['Age']).size())
temp_df = temp_df.reset_index()
temp_df.columns = ["Age", "age_distribution_count"]
temp_df = temp_df.sort_values("age_distribution_count", ascending=False)

# %%
temp_df.head(2)
# Out:
#     Age  age_distribution_count
# 29   35                      46
# 24   30                      44

# %% [markdown]
# # **Answer Q1)**
# # 1) The most common age in the social network is **35**
# # 2) The number of people sharing it is **46**

# %% [markdown]
# # **Q2) List the five people with least posts and reactions combined. (least active people**

# %% [markdown]
# **Reading of the posts table for better understanding**

# %%
posts_df
# Out:
#        User      Post Type   Post Date
# 0         1          Image  1588166977
# 1         1  Status_Change  1588167686
# 2         1           Text  1588168633
# 3         1          Image  1588163570
# 4         1          Image  1588168986
# ...     ...            ...         ...
# 13153  1000          Video  1588167641
# 13154  1000          Image  1588162930
# 13155  1000            Gif  1588164214
# 13156  1000          Video  1588163573
# 13157  1000          Video  1588164524
#
# [13158 rows x 3 columns]

# %% [markdown]
# **Counting of the user id and the number of posts done by them in terms of user id**

# %%
posts_user_count_df = posts_df[["User"]].copy()
posts_user_count_df = pd.DataFrame(posts_user_count_df.groupby(["User"]).size())
posts_user_count_df = posts_user_count_df.reset_index()
posts_user_count_df.columns = ["user_id", "posts_count"]
posts_user_count_df
# Out:
#      user_id  posts_count
# 0          1           18
# 1          2           11
# 2          3           13
# 3          4           15
# 4          5           10
# ..       ...          ...
# 995      996           12
# 996      997           11
# 997      998            8
# 998      999           23
# 999     1000            6
#
# [1000 rows x 2 columns]

# %% [markdown]
# **Reaction table calling here for better understanding of the data**

# %%
reactions_df
# Out:
#        User Reaction Type  Reaction Date
# 0      3741       Comment     1588168107
# 1       711      Emoticon     1588166846
# 2       701      Emoticon     1588163334
# 3      4750      Emoticon     1588168182
# 4       656       Comment     1588162272
# ...     ...           ...            ...
# 26360  2930      Emoticon     1588166570
# 26361  7677          Like     1588165508
# 26362   712          Like     1588164897
# 26363   688      Emoticon     1588164062
# 26364   723       Comment     1588165527
#
# [26365 rows x 3 columns]

# %% [markdown]
# **Reactions count for individual user id and displaying it in the coloumn of "reaction count"**

# %%
reactions_user_count_df = reactions_df[["User"]].copy()
reactions_user_count_df = pd.DataFrame(reactions_user_count_df.groupby(["User"]).size())
reactions_user_count_df = reactions_user_count_df.reset_index()
reactions_user_count_df.columns = ["user_id", "reaction_count"]
reactions_user_count_df
# Out:
#      user_id  reaction_count
# 0         17             122
# 1         65              91
# 2         66             121
# 3         67             130
# 4         68             115
# ..       ...             ...
# 230     8727             121
# 231     8729              98
# 232     8948             135
# 233     9087             113
# 234     9139              97
#
# [235 rows x 2 columns]

# %% [markdown]
# **Now merging of the user dataframe and the reaction data frame to find individual person reaction count with the name**

# %%
user_posts_reactions_df = user_df.merge(reactions_user_count_df,
                                        on = 'user_id',
                                        how="left")
user_posts_reactions_df
# Out:
#          Surname      Name  Age  Subscription Date  user_id  reaction_count
# 0          Smith     Sarah   30         1588157373        1             NaN
# 1         Picard  Francine   32         1588161732        2             NaN
# 2           Roth      Hans   40         1588157337        3             NaN
# 3          Pomme       Ali   28         1588165636        4             NaN
# 4       Di Lillo     Jordi   42         1588156042        5             NaN
# ..           ...       ...  ...                ...      ...             ...
# 995         Kirk       Lee   19         1588160246      996             NaN
# 996        Pomme     Franz   40         1588159625      997             NaN
# 997       Gwahsi    Thomas   40         1588165504      998             NaN
# 998  Beierlorzer  Jean-Luc   32         1588151074      999             NaN
# 999     Thronton     Franz   28         1588171183     1000             NaN
#
# [1000 rows x 6 columns]

# %%
user_df
# Out:
#          Surname      Name  Age  Subscription Date  user_id
# 0          Smith     Sarah   30         1588157373        0
# 1         Picard  Francine   32         1588161732        1
# 2           Roth      Hans   40         1588157337        2
# 3          Pomme       Ali   28         1588165636        3
# 4       Di Lillo     Jordi   42         1588156042        4
# ..           ...       ...  ...                ...      ...
# 995         Kirk       Lee   19         1588160246      995
# 996        Pomme     Franz   40         1588159625      996
# 997       Gwahsi    Thomas   40         1588165504      997
# 998  Beierlorzer  Jean-Luc   32         1588151074      998
# 999     Thronton     Franz   28         1588171183      999
#
# [1000 rows x 5 columns]

# %% [markdown]
# **Merging of the Posts count reaction count and user data frame together**

# %%
user_posts_reactions_df = user_posts_reactions_df.merge(posts_user_count_df,
                                                        on="user_id",
                                                        how="left")
user_posts_reactions_df
# Out:
#          Surname      Name  Age  Subscription Date  user_id  reaction_count  \
# 0          Smith     Sarah   30         1588157373        1             NaN
# 1         Picard  Francine   32         1588161732        2             NaN
# 2           Roth      Hans   40         1588157337        3             NaN
# 3          Pomme       Ali   28         1588165636        4             NaN
# 4       Di Lillo     Jordi   42         1588156042        5             NaN
# ..           ...       ...  ...                ...      ...             ...
# 995         Kirk       Lee   19         1588160246      996             NaN
# 996        Pomme     Franz   40         1588159625      997             NaN
# 997       Gwahsi    Thomas   40         1588165504      998             NaN
# 998  Beierlorzer  Jean-Luc   32         1588151074      999             NaN
# 999     Thronton     Franz   28         1588171183     1000             NaN
#
#      posts_count
# 0             18
# 1             11
# ...

# %% [markdown]
# **Now after merging of the posts cound and reactions count we want to make the NaN values to 0 so that we can calculate the sum of the reaction and posts count**

# %%
user_posts_reactions_df[['reaction_count', 'posts_count']] = user_posts_reactions_df.loc[:,['reaction_count', 'posts_count']].fillna(value=0)
user_posts_reactions_df
# Out:
#          Surname      Name  Age  Subscription Date  user_id  reaction_count  \
# 0          Smith     Sarah   30         1588157373        1             0.0
# 1         Picard  Francine   32         1588161732        2             0.0
# 2           Roth      Hans   40         1588157337        3             0.0
# 3          Pomme       Ali   28         1588165636        4             0.0
# 4       Di Lillo     Jordi   42         1588156042        5             0.0
# ..           ...       ...  ...                ...      ...             ...
# 995         Kirk       Lee   19         1588160246      996             0.0
# 996        Pomme     Franz   40         1588159625      997             0.0
# 997       Gwahsi    Thomas   40         1588165504      998             0.0
# 998  Beierlorzer  Jean-Luc   32         1588151074      999             0.0
# 999     Thronton     Franz   28         1588171183     1000             0.0
#
#      posts_count
# 0             18
# 1             11
# ...

# %% [markdown]
# **The sum of both the posts count and reaction count for finding their combined effect**

# %%
user_posts_reactions_df["added_reaction_post_value"] = user_posts_reactions_df['reaction_count'] + user_posts_reactions_df['posts_count']
user_posts_reactions_df = user_posts_reactions_df.sort_values("added_reaction_post_value")
user_posts_reactions_df
# Out:
#         Surname     Name  Age  Subscription Date  user_id  reaction_count  \
# 918    Thronton    Simon   54         1588158994      919             0.0
# 312  Wellington  Andreas   33         1588161362      313             0.0
# 927  Wellington    Franz   33         1588165035      928             0.0
# 438       Smith   Thomas   37         1588162598      439             0.0
# 307  Wellington     Hans   31         1588159935      308             0.0
# ..          ...      ...  ...                ...      ...             ...
# 652        Kirk     Alok   18         1588158745      653           139.0
# 677        Kirk  Andreas   28         1588155836      678           130.0
# 66       Gwahsi    Agaba   51         1588155646       67           130.0
# 663      Picard      Zoe   46         1588160876      664           130.0
# 641     Mueller      Ali    5         1588145188      642           217.0
#
#      posts_count  added_reaction_post_value
# ...

# %% [markdown]
# # **Answer 2**
#
# 1) The least five people are **Simon Thronton**, **Andreas wellington**, **Thomas Smith**, **Franz Wellington **and** **Hans Wellington**
#
# 2) the combined reactions values are:
#
# **Simon Thronton**  =   **2.0**
#
# **Andreas Wellington**  =  **2.0**
#
# **Franz Wellington**  =  **2.0**
#
# **Thomas Smith** =  **2.0**
#
# **Hans Wellington**  =  **2.0**

# %% [markdown]
# # **Q3) Create a plot of the friendship graph (up to degree 2) for all users:**
# # **named Jean-Luc Picard and Jean-Luc Roth**

# %% [markdown]
# **Finding the Person with the name of Jean-Luc-Picard**

# %%
user_df_person_jane_luc_picard = user_df[(user_df['Name'] == "Jean-Luc Picard")]
user_df_person_jane_luc_picard
# Out:
# Empty DataFrame
# Columns: [Surname, Name, Age, Subscription Date, user_id]
# Index: []

# %% [markdown]
# **There is no person with the name Jean-Luc-Picard**

# %% [markdown]
# **Searching for the person with the name Jean-Luc-Roth**

# %%
user_df_person_jane_luc = user_df[(user_df['Name'] == "Jean-Luc")] 
user_df_person_jane_luc_roth = user_df_person_jane_luc[(user_df_person_jane_luc['Surname'] == "Roth")]
user_df_person_jane_luc_roth
# Out:
#     Surname      Name  Age  Subscription Date  user_id
# 76     Roth  Jean-Luc   40         1588150286       77
# 330    Roth  Jean-Luc   25         1588156458      331
# 369    Roth  Jean-Luc   35         1588155440      370
# 897    Roth  Jean-Luc   29         1588161280      898

# %% [markdown]
# Importing of the libraries for getting the graph

# %%
# libraries
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Build your graph
#friends_df_graph = friends_df[(friends_df['Friend 1'] == 77) | (friends_df['Friend 1'] == 331) | (friends_df['Friend 1'] == 370) | (friends_df['Friend 1'] == 898)] 
#G=nx.from_pandas_edgelist(friends_df_graph, 'Friend 1', 'Friend 2')


friends_df_graph = friends_df[(friends_df['Friend 1'] == 77) ]
G=nx.from_pandas_edgelist(friends_df_graph, 'Friend 1', 'Friend 2')
# Plot it
nx.draw(G, with_labels=True, node_size=4000)
plt.show()

friends_df_graph = friends_df[(friends_df['Friend 1'] == 331) ]
G=nx.from_pandas_edgelist(friends_df_graph, 'Friend 1', 'Friend 2')
# Plot it
nx.draw(G, with_labels=True, node_size=4000)
plt.show()

friends_df_graph = friends_df[(friends_df['Friend 1'] == 370) ]
G=nx.from_pandas_edgelist(friends_df_graph, 'Friend 1', 'Friend 2')
# Plot it
nx.draw(G, with_labels=True, node_size=4000)
plt.show()

friends_df_graph = friends_df[(friends_df['Friend 1'] == 898) ]
G=nx.from_pandas_edgelist(friends_df_graph, 'Friend 1', 'Friend 2')
# Plot it
nx.draw(G, with_labels=True, node_size=4000)
plt.show()

# %% [markdown]
# # **Answer 3:**
#
# # 1) There is no person with the name **Jean luc Picard**
#
# # 2) The person with the name of Jean luc Roth are with the user id of **77, 331, 370, 898**
